# %% [markdown]
# ##Visualização gráfica de dados
#
# Utilizaremos a biblioteca matplotlib do Python, junto com funções do numpy e pandas, para a visualização de dados numéricos e categóricos. Estas visualizações serão posteriormente utilizadas para análise de dados.
# Uma outra biblioteca, chamada seaborn, também pode ser utilizada para os plots dos gráficos. Ela será mencionada em alguns gráficos, mas não é o foco desta aula. Fique a vontade para busca e aprimoramento!

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

# %% [markdown]
# Apenas como primeira interação, vamos plotar um seno com frequência 1/2pi:

# %%
t = np.arange(0,2*np.pi,0.1)
y = np.sin(t)
plt.plot(t, y);

# %% [markdown]
# Um plot gráfico em 2D sempre necessitará de 2 arrays, um para x (eixo horizontal) e um para y (eixo vertical). Plots em 3D também existem, sendo usados para visualização de variações temporais, para visualização de superfícies e para visualização da correlação entre três variáveis. Lidaremos com o plot em 3D ao final da aula.
#
# Seguindo com os gráficos de linha (muito usado), vamos ver como fazer o plot de arrays pré existentes, sem utilizar função, e alterar as configurações do seu plot:

# %%
Anos = []
for i in range(1965,2020):
    Anos.append(i)

Uso_BR = [26.319, 26.386, 26.641, 24.385, 23.901, 25.423, 25.274, 25.726, 24.618,
       25.542, 26.609, 27.747, 29.318, 29.268, 30.743, 33.278, 34.638, 35.656,
       37.685, 38.505, 38.72, 37.149, 36.762, 37.893, 38.184, 43.859, 44.44,
       43.476, 43.727, 43.138, 42.923, 42.655, 42.06, 42.135, 41.706, 41.859,
       37.819, 39.48, 40.939, 40.915, 41.76, 41.636, 42.989, 42.015, 44.945,
       42.868, 42.45, 40.629, 38.35, 37.398, 38.632, 41.467, 41.15, 43.79,
       45.017]

Uso_EUA = [4.049, 3.864, 4.21, 4.008, 4.251, 4.073, 4.273, 4.185, 4.031, 4.544,
           4.633, 4.21, 3.275, 4.066, 4.027, 4.138, 4.059, 4.929, 5.335, 4.993,
           4.459, 4.598, 3.95, 3.431, 4.034, 4.436, 4.435, 3.995, 4.289, 3.99,
           4.472, 4.711, 4.805, 4.41, 4.304, 3.78, 3.203, 3.761, 3.921, 3.85,
           3.962, 4.408, 4.128, 4.75, 5.515, 5.562, 6.559, 6.541, 6.746, 6.859,
           7.047, 7.82, 8.568, 8.467, 8.712]

print(plt.style.available)
#Anos
#Uso_BR
#Uso_EUA
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'petroff10', 'seaborn-v0_8', 'seaborn-v0_8-bright', 'seaborn-v0_8-colorblind', 'seaborn-v0_8-dark', 'seaborn-v0_8-dark-palette', 'seaborn-v0_8-darkgrid', 'seaborn-v0_8-deep', 'seaborn-v0_8-muted', 'seaborn-v0_8-notebook', 'seaborn-v0_8-paper', 'seaborn-v0_8-pastel', 'seaborn-v0_8-poster', 'seaborn-v0_8-talk', 'seaborn-v0_8-ticks', 'seaborn-v0_8-white', 'seaborn-v0_8-whitegrid', 'tableau-colorblind10']

# %%
#plt.style.use('dark_background')
plt.style.use('default')
plt.plot(Anos,Uso_BR,label='Brasil',linestyle='dashdot',color='k',marker='*',
         linewidth=1.5)
plt.plot(Anos,Uso_EUA,label='Estados Unidos',linestyle='--',color='b',
         marker='',linewidth=1)
plt.xlabel(u'Anos')
plt.ylabel(u'Uso de energia renovável em sua matriz energética (%)')
plt.title("Uso de energia renovável")
plt.xlim(1965,2019)
plt.ylim(0,50)
plt.legend()
plt.grid(True)
#plt.tight_layout() # usado apenas para subplots
#plt.savefig('plot1.png')
plt.show() # usar em terminal (como spider - abre janela)

# %% [markdown]
# Altere as configurações de layout, cores, estilos de linhas no gráfico acima para testar.

# %%
#plt.style.use('dark_background')
plt.style.use('default')
plt.plot(Anos,Uso_BR,label='Brasil',linestyle='-',color='g',marker='*',
         linewidth=1)
plt.plot(Anos,Uso_EUA,label='Estados Unidos',linestyle='-',color='r',
         marker='+',linewidth=1)
plt.xlabel(u'Anos')
plt.ylabel(u'Uso de energia renovável em sua matriz energética (%)')
plt.title("Uso de energia renovável")
plt.xlim(1960,2020)
plt.ylim(0,50)
plt.legend()
plt.grid(True)
#plt.tight_layout() - usado apenas para subplots
plt.savefig('plot1.png')
#plt.show()

# %% [markdown]
# Muitos são os casos em que precisamos visualizar mais de um gráfico, um ao lado do outro. Neste caso, usamos subplots.

# %%
def f(t):
    return np.exp(-t) * np.cos(2*np.pi*t)


t1 = np.arange(0.0, 5.0, 0.1)
t2 = np.arange(0.0, 5.0, 0.02)

plt.figure()
plt.subplot(2,1,1)
plt.plot(t1, f(t1), color='b', marker='o')
plt.plot(t2, f(t2), color='g')

plt.subplot(2,1,2) # Organizado em 2 linhas e 1 coluna, agora será modificado o 2º
# O layout é organizado em linhas e colunas, representadas pelo primeiro e
#   segundo argumentos.
# O terceiro argumento representa o índice do gráfico atual.

plt.plot(t2, np.cos(2*np.pi*t2), color='orange', linestyle='--')

plt.tight_layout()

# %% [markdown]
# Mais exemplos com o `subplot()`: [https://www.w3schools.com/python/matplotlib_subplot.asp](https://www.w3schools.com/python/matplotlib_subplot.asp)

# %% [markdown]
# Outro gráfico importante para visualização de dados é o gráfico de barras. No matplotlib, usamos o método `bar()` para este gráfico.
#
# Que tipos de dados se beneficiariam do plot em barras?

# %%
categorias = ['A','B','C','D']
valores = [10, 20, 15, 5]
plt.figure(figsize=(5, 3)) # altera o tamanho da figura
plt.bar(categorias, valores)
plt.xlabel('Grupos')
plt.ylabel('Tamanho')
plt.title('Meu primeiro gráfico de barras')
plt.show()

# %% [markdown]
# As mesmas características que alteramos no gráfico de linhas podemos alterar no gráfico de barras:

# %%
plt.bar(Anos,Uso_BR,label='Brasil',color='g', zorder=-1)
plt.bar(Anos,Uso_EUA,label='Estados Unidos',color='b')
plt.xlabel(u'Anos')
plt.ylabel(u"Porcentagem de uso de energia renovável (%)")
plt.title(u'Uso de energia renovável')
plt.ylim(0,50)
plt.xlim(1960,2020)
plt.legend()
#plt.tight_layout()
plt.show()

# %%
h=[27, 25, 19, 18, 17, 17, 12, 12, 10, 10, 9, 8, 7, 7, 7, 5, 5, 5, 4]
doc = np.arange(1, 20)
doc2 = np.arange(0, 20)
plt.rc('xtick', labelsize=18)
plt.rc('ytick', labelsize=18)
font = {'family' : 'monospace',
        'weight' : 'normal',
        'size'   : 22}

plt.rc('font', **font)
plt.figure(figsize=(10, 6)) # altera o tamanho da figura
plt.bar(doc,h)
plt.xticks(np.arange(min(doc), max(doc)+1, 1.0))
plt.plot(doc2,doc2,color='black')
plt.xlabel(u'Docentes')
plt.ylabel(u"Índice h do docente")
plt.title(u'Índice h2 do Programa')
#plt.ylim(0,50)
plt.xlim(0,20)
# Out:
# (0.0, 20.0)

# %% [markdown]
# Agora outro exemplo, mas lendo um json agora:

# %%
filmes_url = 'https://raw.githubusercontent.com/emanueles/datavis-course/master/assets/files/observable/movies.json'
filmes = pd.read_json(filmes_url)
type(filmes)
# Out:
# pandas.core.frame.DataFrame

# %%
filmes.head()
# Out:
#                                           Film  Year      Genre  \
# 0  Harry Potter and the Deathly Hallows Part 2  2011    Fantasy
# 1                         Mission Impossible 4  2011     Action
# 2                                  Toy Story 3  2010  Animation
# 3                                         2012  2009     Action
# 4                          Alice in Wonderland  2010  Adventure
#
#    Worldwide_Gross_M  Budget_M
# 0               1328       125
# 1                689       145
# 2               1063       200
# 3                768       200
# 4               1024       200

# %%
contagens = filmes.groupby(by='Genre').count()
contagens
# Out:
#            Film  Year  Worldwide_Gross_M  Budget_M
# Genre
# Action       13    13                 13        13
# Adventure     4     4                  4         4
# Animation     8     8                  8         8
# Drama         2     2                  2         2
# Fantasy       1     1                  1         1
# Romance       1     1                  1         1
# Thriller      1     1                  1         1

# %%
plt.figure(figsize=(15, 4)) # altera o tamanho da figura
plt.bar(contagens.index, contagens['Worldwide_Gross_M']);

# %% [markdown]
# Com a biblioteca seaborn, podemos fazer as coisas de forma um pouco mais direta:

# %%
plt.figure(figsize=(13,8))
plt.title('Filmes por gênero em cada ano')
sns.countplot(x="Year", hue='Genre', data=filmes);

# %%
path = 'https://raw.githubusercontent.com/OrlandoIFPR/ml2/main/Dataframes/'
wine_reviews = pd.read_csv(path+ 'winemag-data-130k-v2.csv')
display(wine_reviews.head())
# Out:
#    Unnamed: 0   country                                        description  \
# 0           0     Italy  Aromas include tropical fruit, broom, brimston...
# 1           1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2           2        US  Tart and snappy, the flavors of lime flesh and...
# 3           3        US  Pineapple rind, lemon pith and orange blossom ...
# 4           4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# ...

# %%
plt.rc('xtick', labelsize=9)
plt.rc('ytick', labelsize=9)
font = {'family' : 'sans-serif',
        'weight' : 'normal',
        'size'   : 10}

plt.rc('font', **font)

# %%
plt.figure(figsize=(50,8))
sns.countplot(x="country", data=wine_reviews);

# %% [markdown]
# O histograma é, essencialmente, um gráfico de barras. Contudo, ele tem a especificidade de contar quantidades de valores de dados quantitativos em intervalos de valores. Assim, o histograma permite mostrar quais intervalos são mais frequentes e quais são mais raros, dando uma boa noção de como os valores desse atributo estão distribuídos.

# %%
plt.figure(figsize=(10, 5))
plt.title('Distribuição dos "points" dos vinhos')
plt.hist(wine_reviews['points']);

# %%
plt.figure(figsize=(10, 5))
plt.title('Distribuição de preço dos vinhos')
plt.hist(wine_reviews['price']);

# %%
wine_reviews.describe()
# Out:
#           Unnamed: 0         points          price
# count  129971.000000  129971.000000  120975.000000
# mean    64985.000000      88.447138      35.363389
# std     37519.540256       3.039730      41.022218
# min         0.000000      80.000000       4.000000
# 25%     32492.500000      86.000000      17.000000
# 50%     64985.000000      88.000000      25.000000
# 75%     97477.500000      91.000000      42.000000
# max    129970.000000     100.000000    3300.000000

# %%
plt.figure(figsize=(10, 5))
plt.title('Distribuição de preço dos vinhos')
plt.hist(wine_reviews['price'],bins=1000); #bins é igual ao número de "torres" do histograma

# %%
plt.figure(figsize=(10, 5))
plt.title('Distribuição de preço dos vinhos')
plt.xlim(0,125) # Limitando os valores do eixo x
plt.hist(wine_reviews['price'],bins=2000);

# %% [markdown]
# Os gráficos de pizza também podem ser utilizados para visualização de dados.

# %%
falha = ['Normal', 'Falha 1', 'Falha 2']
quantidade = [110,90,30]
plt.title('Proporção de casos de falha')
plt.pie(x=quantidade, labels = falha);

# %%
plt.figure(figsize=(6,6))
plt.title('Proporção de falhas')
plt.pie(x=quantidade, labels = falha, autopct='%.1f%%')
plt.show()

# %%
plt.pie(x=contagens['Worldwide_Gross_M'], labels = contagens.index, autopct='%1.1f%%',startangle=90, pctdistance=0.90);

# %% [markdown]
# Gráficos de dispersão nos dão uma idéia da relação entre duas variáveis:

# %%
#plt.figure(figsize=(8,5))
plt.title('Relação entre "points" e preço do vinho')
sns.scatterplot(x="points", y="price", data=wine_reviews);
#sns.scatterplot(x="price", y="points", data=wine_reviews)

# %% [markdown]
# E podemos já plotar uma reta de regressão!

# %%
plt.figure(figsize=(8,5))
plt.title('Relação entre "points" e preço do vinho')
sns.regplot(x="points", y="price", data=wine_reviews);
#sns.regplot(x="price", y="points", data=wine_reviews);

# %% [markdown]
# Também podemos aplicar "hues", como feito nos gráficos de barras, para visualizarmos correlações de mais de uma variável.
# sns.scatterplot(x="'___'", y="'_____'", hue = '_____', data='_____')

# %%
uri = 'https://raw.githubusercontent.com/cabrau/curso-analise-visualizacao-dados-python/master/room_data.txt'
room = pd.read_csv(uri)
room.head()
# Out:
#                   date  Temperature  Humidity  Light     CO2  HumidityRatio
# 0  2015-02-04 18:49:59       22.290   27.3900    0.0  621.00       0.004559
# 1  2015-02-04 19:50:00       21.890   27.1000    0.0  548.50       0.004401
# 2  2015-02-04 20:50:00       21.600   26.4725    0.0  509.75       0.004222
# 3  2015-02-04 21:49:59       21.445   25.7450    0.0  488.00       0.004067
# 4  2015-02-04 22:50:00       21.290   25.7000    0.0  467.00       0.004021

# %%
plt.figure(figsize=(10,5))
plt.title('Variação da temperatura ao longo do tempo')
sns.scatterplot(x="date", y="Temperature", data=room);

# %% [markdown]
# A visualização ficou ruim, certo? Vamos tentar no gráfico de linha que já conhecemos?

# %%
plt.plot(room['date'],room['Temperature']);

# %% [markdown]
# Muito melhor! Mas as datas ainda estão ininteligíveis. Vamos consertar isso e já aproveitar para vermos como plotamos gráfico de linha no seaborn no seaborn:

# %%
room['date'] = pd.to_datetime(room['date'])
plt.figure(figsize=(10,5))
plt.title('Variação da temperatura ao longo do tempo')
sns.lineplot(x="date", y="Temperature", data=room);

# %% [markdown]
# Antes de vermos os gráficos 3D, vamos ver os famosos boxplot, utilizando matplotlib e seaborn, utilizando os famosos dados do Titanic, um DataFrame que já existe dentro da biblioteca seaborn.

# %%
titanic = sns.load_dataset("titanic")
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
titanic["age"].isna().sum()
# Out:
# 177

# %%
plt.title('Idade de passageiros em cada classe')
plt.boxplot(titanic['age']);

# %%
titanic[titanic['age'].isna()]
# Out:
#      survived  pclass     sex  age  sibsp  parch     fare embarked   class  \
# 5           0       3    male  NaN      0      0   8.4583        Q   Third
# 17          1       2    male  NaN      0      0  13.0000        S  Second
# 19          1       3  female  NaN      0      0   7.2250        C   Third
# 26          0       3    male  NaN      0      0   7.2250        C   Third
# 28          1       3  female  NaN      0      0   7.8792        Q   Third
# ..        ...     ...     ...  ...    ...    ...      ...      ...     ...
# 859         0       3    male  NaN      0      0   7.2292        C   Third
# 863         0       3  female  NaN      8      2  69.5500        S   Third
# 868         0       3    male  NaN      0      0   9.5000        S   Third
# 878         0       3    male  NaN      0      0   7.8958        S   Third
# 888         0       3  female  NaN      1      2  23.4500        S   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
idades = titanic[titanic['age'].notna()]['age']
idades
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 885    39.0
# 886    27.0
# 887    19.0
# 889    26.0
# 890    32.0
# Name: age, Length: 714, dtype: float64

# %%
plt.title('Idade de passageiros em cada classe')
plt.boxplot(idades);

# %%
plt.title('Idade de passageiros em cada classe por sexo')
sns.boxplot(x="class", y="age", hue = 'sex', data=titanic);

# %% [markdown]
# Por último, vamos ver dois tipos de plot em 3D usando matplotlib (retirados da própria documentação da biblioteca de matplotlib - https://matplotlib.org/2.0.2/mpl_toolkits/mplot3d/tutorial.html).

# %%
from mpl_toolkits.mplot3d import Axes3D
from matplotlib.collections import PolyCollection
from matplotlib import colors as mcolors


fig = plt.figure()
ax = fig.gca(projection='3d')


def cc(arg):
    return mcolors.to_rgba(arg, alpha=0.6)

xs = np.arange(0, 10, 0.4)
verts = []
zs = [0.0, 1.0, 2.0, 3.0]
for z in zs:
    ys = np.random.rand(len(xs))
    ys[0], ys[-1] = 0, 0
    verts.append(list(zip(xs, ys)))

poly = PolyCollection(verts, facecolors=[cc('r'), cc('g'), cc('b'),
                                         cc('y')])
poly.set_alpha(0.7)
ax.add_collection3d(poly, zs=zs, zdir='y')

ax.set_xlabel('X')
ax.set_xlim3d(0, 10)
ax.set_ylabel('Y')
ax.set_ylim3d(-1, 4)
ax.set_zlabel('Z')
ax.set_zlim3d(0, 1)
# Out:
# (0.0, 1.0)

# %%
'''
=================
3D wireframe plot
=================

A very basic demonstration of a wireframe plot.
'''

from mpl_toolkits.mplot3d import axes3d
import matplotlib.pyplot as plt


fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Grab some test data.
X, Y, Z = axes3d.get_test_data(0.05)

# Plot a basic wireframe.
ax.plot_wireframe(X, Y, Z, rstride=10, cstride=10);

# %% [markdown]
# [Site - matplotlib](https://matplotlib.org/stable/)
#
# [Folha de dicas - matplotlib](https://matplotlib.org/cheatsheets/_images/cheatsheets-1.png)
#
# [Site - seaborn](https://seaborn.pydata.org)
