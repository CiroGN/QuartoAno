# %% [markdown]
# # Inteligência Artificial e Aprendizagem de máquina II
#
# *Bacharelado em Ciência da Computação*
#
# **Prof.** João Paulo Orlando

# %% [markdown]
# ## História
#
# * Técnico em informática em 2004 (Integrado)
# * Agrosoft (2004)
# * Smartsoft (2006)
# * Bacharel em Ciência da Computação (2009)
# * Mestre em Computação (2012)
# * Professor EBTT no IFSP (2016)
# * Doutor em Computação (2017)
# * Professor EBTT no IFC (2021)
# * Professor EBTT no IFPR (2023)

# %% [markdown]
# ## Ementa da disciplina
#
#
# * Pré-processamento de dados.
# * Classificação.
# * Regressão.
# * Clusterização.
# * Seleção de características.
# * Tipos de sistemas de aprendizado: supervisionado, não-supervisionado,semi-supervisionado, por reforço, online, em lote, baseado em instâncias, baseado no modelo.
# * Problemas comuns com análise de dados (insuficientes, não-representativos, baixa qualidade, entre outros).
# * Sistemas de Múltiplos Classificadores.
# * Reconhecimento de Padrões.
# * Estratégias para separar o conjunto de dados original em treinamento, validação e teste.
# * Amostragem.
# * Overffiting.
# * Análise estatística de resultados experimentais.
# * Bias.
# * Deep Learning.

# %% [markdown]
# ## Objetivo
#
# Capacitar os alunos a compreender, desenvolver e aplicar algoritmos de aprendizado de máquina para resolver problemas complexos de análise de dados, com ênfase em técnicas de classificação, regressão, clusterização e reconhecimento de padrões, além de introduzir estratégias para garantir a robustez e a qualidade dos modelos desenvolvidos.

# %% [markdown]
# ## Conteúdo Programático
#
# Revisão dos conceitos básicos.
# Tipos de aprendizado: supervisionado, não supervisionado, semi-supervisionado, por reforço.
# Limpeza de dados (tratamento de valores faltantes, remoção de outliers).
# Normalização e padronização.
# Codificação de variáveis categóricas.
# Estratégias de balanceamento de dados.
# Algoritmos de classificação.
# Algoritmos de regressão.
# Comparação e avaliação de modelos.
# Algoritmos de Clusterização
# Métodos de seleção de características.
# Redução de dimensionalidade.
# Avaliação da importância de características.
# Problemas Comuns na Análise de Dados.
# Sistemas de Múltiplos Classificadores.
# Reconhecimento de Padrões.
# Divisão dos Dados: Treinamento, Validação e Teste.
# Estratégias de amostragem.
# Técnicas de otimização de parâmetros.
# Conceito de overfitting e underfitting.
# Estratégias para evitar overfitting: regularização, early stopping, validação cruzada.
# Medidas de desempenho: acurácia, precisão, recall, F1-score, curva ROC.
# Interpretação dos resultados.

# %% [markdown]
# ## Bibliografia Básica
#
# RUSSELL, Stuart J.; NORVIG, Peter. Inteligência artificial. Rio de Janeiro: Elsevier, 2013. 988p. ISBN 9788535237016 (broch.).
#
# FACELI, Katti; LORENA, Ana Carolina; GAMA, João; CARVALHO, André Ponce de Leon F. de. Inteligência artificial: uma abordagem de aprendizado de máquina. Rio de Janeiro: LTC, 2011. 378 p. ISBN 9788521618805 (broch.).
#
# ROCHA, Miguel; FERREIRA, Pedro G. Análise e exploração de dados com R. Lisboa: FCA,2017. 360 p. ISBN 9789728638 (broch.).

# %% [markdown]
# ## Bibliografia Complementar
#
# ALEXANDRE MOREIRA DE MENEZES. Os Paradigmas de Aprendizagem de Algoritmo
# Computacional. Editora Blucher 198 ISBN 9788580391039.
#
# ALVES, Lynn (org.); Coutinho, Isa de Jesus (org.). Jogos digitais e aprendizagem: fundamentos para uma prática baseada em evidências. Papirus Editora 324 ISBN 9788544902639.
#
# GEORGE F. LUGER. Inteligência artificial, 6ª edição. Editora Pearson 636 ISBN
# 9788581435503.
#
# MEDEIROS, Luciano Frontino de. Inteligência artificial aplicada: uma abordagem introdutória. Editora Intersaberes 263 ISBN 9788559728002.

# %% [markdown]
# ## Bibliografia Online
# [https://jakevdp.github.io/PythonDataScienceHandbook](https://jakevdp.github.io/PythonDataScienceHandbook)

# %% [markdown]
# ## Metodologia
#
# Aulas expositivas teóricas com exemplos práticos.
#
# Estudo de casos reais de aplicação de aprendizado de máquina e IA.
#
# Implementação de algoritmos e experimentos utilizando Python e bibliotecas populares.

# %% [markdown]
# ## Critérios e formas de avaliação
#
#
# Atividades práticos e/ou teóricas.
#
# Trabalho final
#
# Critérios de avaliação:
# * Aplicação correta dos conceitos técnicos abordados.
# * Criatividade e inovação na construção dos modelos.
# * Organização do código.
#
# **Importante**: Para aprovação é necessário o conceito igual ou superior à C.

# %% [markdown]
# ## Material de de aula
#
#
# Classroom
#
# Acesso deve ser feito com o e-mail institucional

# %% [markdown]
# ## Atendimentos
#
# Por e-mail: joaopauloorlando@gmail.com ou joao.orlando@ifpr.edu.br
#
# Na sala dos professores ou das coordenações nos seguintes horários:
# Quarta-feira das 13:00 horas até 15:00 horas e
# Quinta-feira das 13:00 horas até 15:00 horas.
#
# Por WhatsApp, não estarei atendendo, salvo exceções quando autorizar e passar o número.

# %% [markdown]
# ##Dúvidas

# %% [markdown]
# Modo diferentes de explicar Aprendizado de Máquina:
#
# [Computer Scientist Explains Machine Learning in 5 Levels of Difficulty](https://www.youtube.com/watch?v=5q87K1WaoFI)
